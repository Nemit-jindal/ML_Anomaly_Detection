# %% [markdown]
# <a href="https://colab.research.google.com/github/Nemit-jindal/ML_Anomaly_Detection/blob/main/AnomalyDetection_using_DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_circles

x,y=make_circles(n_samples=750,factor=0.3,noise=0.1)

# %%
plt.scatter(x[:,0],x[:,1])

# %%
dbscan=DBSCAN(eps=0.1)
dbscan.fit_predict(x)
# Out:
# array([ 0,  0,  0,  0,  0,  1,  0,  2, -1,  3,  4,  0, 11,  0, 12,  0,  0,
#        12,  0,  0,  0,  1,  0,  0,  5,  9,  0,  0,  0,  0,  0, 13,  0,  0,
#         0,  6,  0,  0,  4,  0,  0,  7,  2,  5,  8,  0,  2,  9,  0,  2,  0,
#         0,  0,  0,  4,  0, -1,  1, 10,  0,  0,  2, 11,  6,  7, -1,  1,  0,
#         0,  0,  6, -1,  0,  0,  0, -1, 12,  4,  9,  0,  0,  0,  0,  0,  0,
#         9,  4, 13, 10,  3,  2, 13,  1,  0,  0,  0,  0,  0,  4,  0,  0,  0,
#         0, 11, 12,  9,  0,  0,  7,  4, 11,  0, 13,  4,  0,  0,  4,  0,  0,
#         0,  0,  4, 10, 11, -1,  0,  5,  9,  0,  0,  0,  0, -1,  0,  0,  0,
#         3, 11, 11, 13,  0,  0,  6,  0,  1,  0,  4, 13, 11,  0,  0,  0,  6,
#        12,  4,  0, 10,  1,  0,  6,  0,  9,  0, -1,  0,  0,  0,  6,  0,  0,
#         7, 10, -1,  0, 13,  0,  7,  4,  3,  0,  1,  0,  0, 10,  0,  0,  1,
#         1, -1,  0,  0,  0,  3,  3,  0,  0,  3,  0,  0,  0,  4, 13,  6,  0,
# ...

# %%
dbscan.labels_
# Out:
# array([ 0,  0,  0,  0,  0,  1,  0,  2, -1,  3,  4,  0, 11,  0, 12,  0,  0,
#        12,  0,  0,  0,  1,  0,  0,  5,  9,  0,  0,  0,  0,  0, 13,  0,  0,
#         0,  6,  0,  0,  4,  0,  0,  7,  2,  5,  8,  0,  2,  9,  0,  2,  0,
#         0,  0,  0,  4,  0, -1,  1, 10,  0,  0,  2, 11,  6,  7, -1,  1,  0,
#         0,  0,  6, -1,  0,  0,  0, -1, 12,  4,  9,  0,  0,  0,  0,  0,  0,
#         9,  4, 13, 10,  3,  2, 13,  1,  0,  0,  0,  0,  0,  4,  0,  0,  0,
#         0, 11, 12,  9,  0,  0,  7,  4, 11,  0, 13,  4,  0,  0,  4,  0,  0,
#         0,  0,  4, 10, 11, -1,  0,  5,  9,  0,  0,  0,  0, -1,  0,  0,  0,
#         3, 11, 11, 13,  0,  0,  6,  0,  1,  0,  4, 13, 11,  0,  0,  0,  6,
#        12,  4,  0, 10,  1,  0,  6,  0,  9,  0, -1,  0,  0,  0,  6,  0,  0,
#         7, 10, -1,  0, 13,  0,  7,  4,  3,  0,  1,  0,  0, 10,  0,  0,  1,
#         1, -1,  0,  0,  0,  3,  3,  0,  0,  3,  0,  0,  0,  4, 13,  6,  0,
# ...

# %%
plt.scatter(x[:,0],x[:,1],c=dbscan.labels_)

# %%
plt.scatter(x[:,0],x[:,1],c=y)
